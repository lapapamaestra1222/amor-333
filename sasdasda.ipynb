# %%
# SAN VALENTIN!
from IPython.display import display, HTML

html_code = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <style>
        body {
            margin: 0;
            padding: 0;
            display: flex;
            justify-content: center;
            align-items: center;
            height: 100vh;
            background-image: url('https://ar.pinterest.com/pin/48906345948174682/');
            background-size: cover;
            background-position: center;
            color: red;
            font-family: Arial, sans-serif;
            text-align: center;
            flex-direction: column;
        }
        .image {
            width: 80%;
            max-width: 500px;
            margin-bottom: 20px;
        }
        .message {
            font-size: 50px;
            font-weight: bold;
            margin-top: 30px;
        }
        .options {
            display: flex;
            justify-content: center;
            gap: 30px;
            font-size: 24px;
            font-weight: bold;
        }
        .options a {
            text-decoration: none;
            color: red;
            font-size: 30px;
        }
    </style>
</head>
<body>
    <p class="message">¿Quieres ser mi San Valentín?</p>
    <img src="https://i.pinimg.com/736x/06/fa/2d/06fa2d379c8f74775a6a6ab16954f871.jpg" class="image" alt="San Valentín">
    <div class="options">
        <a href="https://www.youtube.com/watch?v=J5mgwjSpjsU">Sí</a>
        <a href="https://www.youtube.com/watch?v=SssVhVACJIc">No</a>
    </div>
</body>
</html>
"""

display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             margin: 0;
#             padding: 0;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             background-image: url('https://ar.pinterest.com/pin/48906345948174682/');
#             background-size: cover;
#             background-position: center;
#             color: red;
#             font-family: Arial, sans-serif;
#             text-align: center;
#             flex-direction: column;
#         }
#         .image {
#             width: 80%;
#             max-width: 500px;
#             margin-bottom: 20px;
#         }
#         .message {
#             font-size: 50px;
#             font-weight: bold;
#             margin-top: 30px;
#         }
#         .options {
#             display: flex;
# ...
